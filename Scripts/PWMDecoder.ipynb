# %%
import cv2
import numpy as np
from PIL import Image
import scipy
import scipy.fftpack
from pylab import plot, show, title, xlabel, ylabel, subplot
from matplotlib import pyplot as plt
import pylab
from scipy import fft, arange, signal
import numpy


# %matplotlib inline

file_name = "/home/mike/Documents/Experiments/distanceComparison/big_led/20cm/1000.jpg"

gray_image = cv2.imread(file_name, cv2.IMREAD_GRAYSCALE)
plt.imshow(gray_image, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

print "rows:", gray_image.shape[0], "columns:", gray_image.shape[1]

gray_middle_pixel_values = []
#for every row 
for i in range (0, gray_image.shape[0]):
    #get the middle column pixel value
    #print blur[i,gray_image.shape[1]/2-1]
    gray_middle_pixel_values.append(gray_image[i,gray_image.shape[1]/2-1])

print sum(gray_middle_pixel_values) / float(len(gray_middle_pixel_values))
# Out:
# rows: 1200 columns: 1600
# 4.345

# %%
dst = cv2.fastNlMeansDenoising(gray_image,None,10,7,21)

plt.imshow(dst, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %%
blur = cv2.blur(gray_image,(10,10))
plt.imshow(blur, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %%
thresh, imthresh = cv2.threshold(blur,10,255,cv2.THRESH_BINARY)
#thresh, imthresh = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(imthresh, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %%
threshold_middle_pixel_values = []
gray_middle_pixel_values = []

print gray_image.shape[1]/2-1

#for every row 
for i in range (0, gray_image.shape[0]):
    #get the middle column pixel value
    #print blur[i,gray_image.shape[1]/2-1]
    threshold_middle_pixel_values.append(imthresh[i,gray_image.shape[1]/2-1])
    gray_middle_pixel_values
    
    
#plot blur pixels
plt.plot(threshold_middle_pixel_values)
plt.ylabel('blur pixels')
plt.show()


#print threshold_middle_pixel_values

countOn =0
countOff = 0
y = 0
x = 0
for i in range (0, len(threshold_middle_pixel_values)-1):
    if threshold_middle_pixel_values[i]==0 and  threshold_middle_pixel_values[i+1]==255:
        x = i
    if threshold_middle_pixel_values[i]==255 and  threshold_middle_pixel_values[i+1]==0:
        y = i
        print "Width", y - x


for i in range (0, len(threshold_middle_pixel_values)-1):
    if threshold_middle_pixel_values[i]==0 and  threshold_middle_pixel_values[i+1]==255:
        print i
# Out:
# 799
# Width 13
# Width 22
# Width 25
# Width 25
# Width 21
# Width 12
# 472
# 505
# 543
# 581
# 621
# 665
